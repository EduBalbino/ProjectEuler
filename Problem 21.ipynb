# %%
def get_divisors(n):
    divisors = set()
    for x in range (1, int(n/2 + 1)):
        if n%x == 0:
            divisors.add(x)
    return divisors

# %%
abundant_numbers = [[x] for x in range(1, 10001)]

# %%
amicable_numbers = []

# %%
for x in range(10000):
    numbers[x].append(( a:= sum(get_divisors(x + 1))))
    if a < x + 1 and numbers[a - 1][1] == x + 1:
        amicable_numbers.extend([x + 1, a])

# %%
sum(amicable_numbers)
# Out:
# 31626

# %%
numbers = [[x] for x in range(1, 28123 + 1)]

# %%
abundant_numbers = []

# %%
for x in range(1, 28123 + 1):
    if (sum(get_divisors(x + 1))) > x + 1:
        abundant_numbers.append(x + 1)

# %%
sums_of_two_abundant_numbers = [x + y for x in abundant_numbers for y in abundant_numbers if x != y]

# %%
sum(list(range(1, 28123 + 1))) - sum(sums_of_two_abundant_numbers)
# Out:
# -1362619952070

# %%
sums_of_two_abundant_numbers[5000:6000]
# Out:
# [20202,
#  20208,
#  20212,
#  20214,
#  20220,
#  20226,
#  20228,
#  20232,
#  20236,
#  20238,
#  20242,
#  20244,
#  20250,
#  20252,
#  20256,
#  20262,
#  20268,
#  20272,
#  20274,
#  20280,
#  20284,
#  20286,
#  20292,
#  20298,
#  20304,
#  20310,
#  20312,
#  20316,
#  20322,
#  20328,
#  20332,
#  20334,
#  20340,
#  20344,
#  20346,
#  20348,
#  20352,
#  20358,
#  20362,
#  20364,
#  20368,
#  20370,
#  20372,
#  20376,
#  20380,
#  20382,
#  20388,
#  20392,
#  20394,
#  20396,
#  20400,
#  20406,
#  20412,
#  20418,
#  20424,
#  20428,
#  20430,
#  20432,
#  20436,
#  20442,
#  20448,
#  20452,
#  20454,
#  20460,
#  20466,
#  20472,
#  20478,
#  20480,
#  20484,
#  20487,
#  20490,
#  20492,
#  20494,
#  20496,
#  20500,
#  20502,
#  20508,
#  20512,
#  20514,
#  20516,
#  20520,
#  20522,
#  20526,
#  20532,
#  20536,
#  20538,
#  20544,
#  20550,
#  20552,
#  20556,
#  20562,
#  20564,
#  20568,
#  20572,
#  20574,
#  20580,
#  20582,
#  20586,
#  20592,
#  20598,
# ...

# %%
solution = []
for i in numbers:
    for i in sums_of_two_abundant_numbers:
        solution.append(i)
# Out:
#   File "<ipython-input-9-3d6ae1eb152f>", line 3
#     for i not in sums_of_two_abundant_numbers:
#           ^
# SyntaxError: invalid syntax
